# %%
# Importamos pandas
import pandas as pd

# %%
# Podemos checar la versión de pandas
pd.__version__
# Out:
# '0.23.4'

# %%
# Ahora para poder hacer un data frames o marco de datos como en el lenguaje R
df_profesores1 = pd.DataFrame(
    {
        "nombre": ["Jaime","Alma","Armando","Sergio","Oscar"],
        "apellido_paterno": ["Minor","Vazquez","Alvarez", "Moreno", "Martinez"],
        "apellido_materno": ["Gomez","Sanchez","Galvan","Soto", "Campos"]        
    }
)
df_profesores1
# Out:
#     nombre apellido_paterno apellido_materno
# 0    Jaime            Minor            Gomez
# 1     Alma          Vazquez          Sanchez
# 2  Armando          Alvarez           Galvan
# 3   Sergio           Moreno             Soto
# 4    Oscar         Martinez           Campos

# %%
# Tambien podemos hacer data frames con listas tipo Diccionarios
df_profesores2 = pd.DataFrame([["Jaime", "Minor", "Gomez"], ["Alma", "Vazquez", "Sanchez"], ["Armando", "Alvarez", "Galvan"],
                              ["Sergio", "Moreno", "Soto"], ["Oscar", "Martinez", "Campos"]], 
                              columns=["nombre", "apellido_paterno", "apellido_materno"])
df_profesores2
# Out:
#     nombre apellido_paterno apellido_materno
# 0    Jaime            Minor            Gomez
# 1     Alma          Vazquez          Sanchez
# 2  Armando          Alvarez           Galvan
# 3   Sergio           Moreno             Soto
# 4    Oscar         Martinez           Campos

# %%
# Ahora veremos el tipo de dato del DataFrame
type(df_profesores1)
# Out:
# pandas.core.frame.DataFrame

# %%
# Vamos a ver este archico csv
# !type csv_camaras_1.csv
# Out:
# Model,Release date,Max resolution,Low resolution,Effective pixels,Zoom wide (W)
# Agfa ePhoto 1280,1997,1024,640,0,38
# Agfa ePhoto 1680,1998,1280,640,1,38
# Agfa ePhoto CL18,2000,640,0,0,45
# Agfa ePhoto CL30,1999,1152,640,0,35
# Agfa ePhoto CL30 Clik!,1999,1152,640,0,43
# Agfa ePhoto CL45,2001,1600,640,1,51
# Agfa ePhoto CL50,1999,1280,640,1,34
# Canon PowerShot 350,1997,640,0,0,42
# Canon PowerShot 600,1996,832,640,0,50
# Canon PowerShot A10,2001,1280,1024,1,35
# Canon PowerShot A100,2002,1280,1024,1,39
# Canon PowerShot A20,2001,1600,1024,1,35
# Canon PowerShot A200,2002,1600,1024,1,39
# Canon PowerShot A30,2002,1280,1024,1,35
# Canon PowerShot A300,2003,2048,1600,3,33
# Canon PowerShot A310,2004,2048,1600,3,33
# Canon PowerShot A40,2002,1600,1024,1,35
# Canon PowerShot A400,2004,2048,1600,3,45
# Canon PowerShot A410,2005,2048,1600,3,41
# Canon PowerShot A420,2006,2272,1600,4,39
# Canon PowerShot A430,2006,2272,1600,4,39
# Canon PowerShot A450,2007,2592,2048,5,38
# ...

# %%
# Ahora vamos a importarlo
df_camaras_1 = pd.read_csv("csv_camaras_1.csv")
df_camaras_1
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997            1024             640
# 1           Agfa ePhoto 1680          1998            1280             640
# 2           Agfa ePhoto CL18          2000             640               0
# 3           Agfa ePhoto CL30          1999            1152             640
# 4     Agfa ePhoto CL30 Clik!          1999            1152             640
# 5           Agfa ePhoto CL45          2001            1600             640
# 6           Agfa ePhoto CL50          1999            1280             640
# 7        Canon PowerShot 350          1997             640               0
# 8        Canon PowerShot 600          1996             832             640
# 9        Canon PowerShot A10          2001            1280            1024
# 10      Canon PowerShot A100          2002            1280            1024
# ...

# %%
# Para ver los primeros datos de un DataFrame, tambien se le puede pasar como parametro un numero especifico de registros,
# Por defecto nos da 5
df_camaras_1.head()
# Out:
#                     Model  Release date  Max resolution  Low resolution  \
# 0        Agfa ePhoto 1280          1997            1024             640
# 1        Agfa ePhoto 1680          1998            1280             640
# 2        Agfa ePhoto CL18          2000             640               0
# 3        Agfa ePhoto CL30          1999            1152             640
# 4  Agfa ePhoto CL30 Clik!          1999            1152             640
#
#    Effective pixels  Zoom wide (W)
# 0                 0             38
# 1                 1             38
# 2                 0             45
# 3                 0             35
# 4                 0             43

# %%
# Para ver los ultimos registros de un DataFrame, tambien se le puede pasar como parametro un numero especifico de registros,
# Por defecto nos da 5
df_camaras_1.tail()
# Out:
#                 Model  Release date  Max resolution  Low resolution  \
# 1033  Toshiba PDR-M65          2001            2048            1024
# 1034  Toshiba PDR-M70          2000            2048            1024
# 1035  Toshiba PDR-M71          2001            2048            1024
# 1036  Toshiba PDR-M81          2001            2400            1200
# 1037  Toshiba PDR-T10          2002            1600             800
#
#       Effective pixels  Zoom wide (W)
# 1033                 3             38
# 1034                 3             35
# 1035                 3             35
# 1036                 3             35
# 1037                 1             38

# %%
# Ahora para ver los tipos de datos de nuestro data frame
df_camaras_1.dtypes
# Out:
# Model               object
# Release date         int64
# Max resolution       int64
# Low resolution       int64
# Effective pixels     int64
# Zoom wide (W)        int64
# dtype: object

# %%
# Para ver estadisticas basicas de nuetro data frame
df_camaras_1.describe()
# Out:
#        Release date  Max resolution  Low resolution  Effective pixels  \
# count   1038.000000     1038.000000     1038.000000       1038.000000
# mean    2003.590559     2474.672447     1773.936416          4.596339
# std        2.724755      759.513608      830.897955          2.844044
# min     1994.000000        0.000000        0.000000          0.000000
# 25%     2002.000000     2048.000000     1120.000000          3.000000
# 50%     2004.000000     2560.000000     2048.000000          4.000000
# 75%     2006.000000     3072.000000     2560.000000          7.000000
# max     2007.000000     5616.000000     4992.000000         21.000000
#
#        Zoom wide (W)
# count    1038.000000
# mean       32.963391
# std        10.333149
# min         0.000000
# 25%        35.000000
# 50%        36.000000
# 75%        38.000000
# max        52.000000

# %%
# Para ver el indice generado por defecto
df_camaras_1.index
# Out:
# RangeIndex(start=0, stop=1038, step=1)

# %%
# Para visualizar un registro especifico de nuestro data frame 
# Le pasamos el indice generado por defecto
df_camaras_1.loc[25]
# Out:
# Model               Canon PowerShot A510
# Release date                        2005
# Max resolution                      2048
# Low resolution                      1600
# Effective pixels                       3
# Zoom wide (W)                         35
# Name: 25, dtype: object

# %%
# Para nostros cambiar el indice por defecto a uno que nosotros queramos designar
# Le pasamos de parametro la columna de los datos que queramos usar como indice
# Pero se guardara en otra variable
df2_camaras_1 = df_camaras_1.set_index("Model")

# %%
# Ahora para volver a seleccionar un elemento especifico 
# Se le pasa el indice que nostros hayamos seleccionado
df2_camaras_1.loc["Canon PowerShot A550"]
# Out:
# Release date        2007
# Max resolution      3072
# Low resolution      2592
# Effective pixels       7
# Zoom wide (W)         35
# Name: Canon PowerShot A550, dtype: int64

# %%
# Ahora para seleccionar un elemento especifico en el nuevo data frame con un indice numerico
df2_camaras_1.iloc[685]
# Out:
# Release date        2007
# Max resolution      3264
# Low resolution      2560
# Effective pixels       8
# Zoom wide (W)         36
# Name: Olympus Stylus 820, dtype: int64

# %%
# Para seleccionar una  o varias propiedades
# Si se quieren mas df_camaras_1["Max resolution", "Model", "Release date"]
df_camaras_1["Max resolution"]
# Out:
# 0       1024
# 1       1280
# 2        640
# 3       1152
# 4       1152
# 5       1600
# 6       1280
# 7        640
# 8        832
# 9       1280
# 10      1280
# 11      1600
# 12      1600
# 13      1280
# 14      2048
# 15      2048
# 16      1600
# 17      2048
# 18      2048
# 19      2272
# 20      2272
# 21      2592
# 22      2592
# 23      1024
# 24      1280
# 25      2048
# 26      2272
# 27      2592
# 28      2816
# 29      3072
#         ...
# 1008     640
# 1009     640
# 1010     640
# 1011    1024
# 1012    1024
# 1013    1280
# 1014    1280
# 1015    1280
# 1016    1280
# 1017    1472
# 1018    1600
# 1019    1600
# 1020    2048
# 1021    2048
# 1022    2400
# 1023    2560
# 1024    1280
# 1025    1280
# 1026    1600
# 1027    1729
# 1028    1280
# 1029    1600
# 1030    1600
# 1031    1792
# 1032    1792
# 1033    2048
# 1034    2048
# 1035    2048
# 1036    2400
# 1037    1600
# Name: Max resolution, Length: 1038, dtype: int64

# %%
# Tambien se puede hacer así pero si la columna que se desea obtener no tiene una palabra resevada o tiene espacios
df_camaras_1.Model
# Out:
# 0             Agfa ePhoto 1280
# 1             Agfa ePhoto 1680
# 2             Agfa ePhoto CL18
# 3             Agfa ePhoto CL30
# 4       Agfa ePhoto CL30 Clik!
# 5             Agfa ePhoto CL45
# 6             Agfa ePhoto CL50
# 7          Canon PowerShot 350
# 8          Canon PowerShot 600
# 9          Canon PowerShot A10
# 10        Canon PowerShot A100
# 11         Canon PowerShot A20
# 12        Canon PowerShot A200
# 13         Canon PowerShot A30
# 14        Canon PowerShot A300
# 15        Canon PowerShot A310
# 16         Canon PowerShot A40
# 17        Canon PowerShot A400
# 18        Canon PowerShot A410
# 19        Canon PowerShot A420
# 20        Canon PowerShot A430
# 21        Canon PowerShot A450
# 22        Canon PowerShot A460
# 23          Canon PowerShot A5
# 24         Canon PowerShot A50
# 25        Canon PowerShot A510
# 26        Canon PowerShot A520
# 27        Canon PowerShot A530
# 28        Canon PowerShot A540
# 29        Canon PowerShot A550
# ...

# %%
# Y este es su tipo de dato 
type(df_camaras_1.Model)
# Out:
# pandas.core.series.Series

# %%
# Para hacer filtrados de informacíon 
df_camaras_1[df_camaras_1["Release date"] <= 1996]
# Out:
#                    Model  Release date  Max resolution  Low resolution  \
# 8    Canon PowerShot 600          1996             832             640
# 167         Casio QV-300          1996             640             320
# 393         Kodak DCS420          1994            1524               0
# 394         Kodak DCS460          1995            3060               0
# 603       Olympus D-200L          1996             640             320
# 604       Olympus D-300L          1996            1024             512
#
#      Effective pixels  Zoom wide (W)
# 8                   0             50
# 167                 0             47
# 393                 1              0
# 394                 6              0
# 603                 0             36
# 604                 0             36

# %%
# Para hacer filtrados con mas de una condicion
df_camaras_1[(df_camaras_1["Release date"]<= 1996)&(df_camaras_1["Max resolution"]<= 1000)]
# Out:
#                    Model  Release date  Max resolution  Low resolution  \
# 8    Canon PowerShot 600          1996             832             640
# 167         Casio QV-300          1996             640             320
# 603       Olympus D-200L          1996             640             320
#
#      Effective pixels  Zoom wide (W)
# 8                   0             50
# 167                 0             47
# 603                 0             36

# %%
# Tambien podemos hacer lo mismo con el metodo query
modelo = "Canon PowerShot A460"
df_camaras_1.query("Model == @modelo")
# Out:
#                    Model  Release date  Max resolution  Low resolution  \
# 22  Canon PowerShot A460          2007            2592            2048
#
#     Effective pixels  Zoom wide (W)
# 22                 5             38

# %%
# Para ordenar el data frame por alguna comulna especifica
df_camaras_1.sort_values(by="Max resolution", ascending=True)
# Out:
#                            Model  Release date  Max resolution  \
# 370                 Kodak CX7220          2004               0
# 477            Nikon Coolpix 100          1997             512
# 193            Epson PhotoPC 550          1997             640
# 1008           Sony Mavica FD-71          1998             640
# 482            Nikon Coolpix 300          1997             640
# 176                 Casio QV-770          1998             640
# 429                    Kodak mc3          2001             640
# 192            Epson PhotoPC 500          1997             640
# 1009           Sony Mavica FD-73          1999             640
# 174                 Casio QV-700          1997             640
# 167                 Casio QV-300          1996             640
# 603               Olympus D-200L          1996             640
# 2               Agfa ePhoto CL18          2000             640
# 1010           Sony Mavica FD-75          2001             640
# ...

# %%
# Por ejemplo para sumar los pixeles de la resolucion mayor por año
df_camaras_1.groupby("Release date")["Max resolution"].sum()
# Out:
# Release date
# 1994      1524
# 1995      3060
# 1996      3136
# 1997      9344
# 1998     41040
# 1999     77928
# 2000    109592
# 2001    158665
# 2002    186508
# 2003    228637
# 2004    357441
# 2005    393919
# 2006    461672
# 2007    536244
# Name: Max resolution, dtype: int64

# %%
# Por ejemplo para aplicar una funcion a un data frame
# Que lo que va a hacer es agregar una columna a el data frame con la inicial de cada camara
df_camaras_1["letra_camara"] = df_camaras_1.Model.apply(lambda nombre: nombre[0])

# %%
# Ahora vamos a mostralo 
df_camaras_1.head(20)
# Out:
#                      Model  Release date  Max resolution  Low resolution  \
# 0         Agfa ePhoto 1280          1997            1024             640
# 1         Agfa ePhoto 1680          1998            1280             640
# 2         Agfa ePhoto CL18          2000             640               0
# 3         Agfa ePhoto CL30          1999            1152             640
# 4   Agfa ePhoto CL30 Clik!          1999            1152             640
# 5         Agfa ePhoto CL45          2001            1600             640
# 6         Agfa ePhoto CL50          1999            1280             640
# 7      Canon PowerShot 350          1997             640               0
# 8      Canon PowerShot 600          1996             832             640
# 9      Canon PowerShot A10          2001            1280            1024
# 10    Canon PowerShot A100          2002            1280            1024
# 11     Canon PowerShot A20          2001            1600            1024
# ...

# %%
# Ahora vamos a borrar la columna que hicimos
# El 0 es para borrar filas y el 1 para borrar columnas
# El inplace es para no tener que asignarlo a otra variable
df_camaras_1.drop("letra_camara", axis=1, inplace=True)
df_camaras_1
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997            1024             640
# 1           Agfa ePhoto 1680          1998            1280             640
# 2           Agfa ePhoto CL18          2000             640               0
# 3           Agfa ePhoto CL30          1999            1152             640
# 4     Agfa ePhoto CL30 Clik!          1999            1152             640
# 5           Agfa ePhoto CL45          2001            1600             640
# 6           Agfa ePhoto CL50          1999            1280             640
# 7        Canon PowerShot 350          1997             640               0
# 8        Canon PowerShot 600          1996             832             640
# 9        Canon PowerShot A10          2001            1280            1024
# 10      Canon PowerShot A100          2002            1280            1024
# ...

# %%
# Vamos a mostrar otro archivo csv
# !type csv_camaras_2.csv
# Out:
# Model,Zoom tele (T),Normal focus range,Macro focus range,Storage included,Weight (inc. batteries),Dimensions,Price
# Agfa ePhoto 1280,114,70,40,4,420,95,179
# Agfa ePhoto 1680,114,50,0,4,420,158,179
# Agfa ePhoto CL18,45,0,0,2,0,0,179
# Agfa ePhoto CL30,35,0,0,4,0,0,269
# Agfa ePhoto CL30 Clik!,43,50,0,40,300,128,1299
# Agfa ePhoto CL45,51,50,20,8,270,119,179
# Agfa ePhoto CL50,102,0,0,8,0,0,179
# Canon PowerShot 350,42,70,3,2,320,93,149
# Canon PowerShot 600,50,40,10,1,460,160,139
# Canon PowerShot A10,105,76,16,8,375,110,139
# Canon PowerShot A100,39,20,5,8,225,110,139
# Canon PowerShot A20,105,76,16,8,375,110,139
# Canon PowerShot A200,39,20,5,8,225,110,139
# Canon PowerShot A30,105,76,16,8,350,110,139
# Canon PowerShot A300,33,20,5,32,225,111,139
# Canon PowerShot A310,33,0,5,0,205,110,139
# Canon PowerShot A40,105,76,16,8,350,110,139
# Canon PowerShot A400,100,0,5,16,255,107,139
# Canon PowerShot A410,131,0,1,16,195,103,139
# Canon PowerShot A420,125,47,1,16,200,103,139
# ...

# %%
df_camaras_2 = pd.read_csv("csv_camaras_2.csv")
df_camaras_2
# Out:
#                        Model  Zoom tele (T)  Normal focus range  \
# 0           Agfa ePhoto 1280            114                  70
# 1           Agfa ePhoto 1680            114                  50
# 2           Agfa ePhoto CL18             45                   0
# 3           Agfa ePhoto CL30             35                   0
# 4     Agfa ePhoto CL30 Clik!             43                  50
# 5           Agfa ePhoto CL45             51                  50
# 6           Agfa ePhoto CL50            102                   0
# 7        Canon PowerShot 350             42                  70
# 8        Canon PowerShot 600             50                  40
# 9        Canon PowerShot A10            105                  76
# 10      Canon PowerShot A100             39                  20
# 11       Canon PowerShot A20            105                  76
# 12      Canon PowerShot A200             39                  20
# 13       Canon PowerShot A30            105                  76
# ...

# %%
# Tambien podemos unir dataframes como un JOIN en MySQL
# Left_on es para definir la columna con la que queremos unirlo del data frame que esta afuera del parentesis
# Mientras que right_on es para definir la columna con la que queremos unirlo del data frame que esta dentro del parentesis
df_merged = df_camaras_1.merge(df_camaras_2, left_on="Model", right_on="Model")
df_merged
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997            1024             640
# 1           Agfa ePhoto 1680          1998            1280             640
# 2           Agfa ePhoto CL18          2000             640               0
# 3           Agfa ePhoto CL30          1999            1152             640
# 4     Agfa ePhoto CL30 Clik!          1999            1152             640
# 5           Agfa ePhoto CL45          2001            1600             640
# 6           Agfa ePhoto CL50          1999            1280             640
# 7        Canon PowerShot 350          1997             640               0
# 8        Canon PowerShot 600          1996             832             640
# 9        Canon PowerShot A10          2001            1280            1024
# 10      Canon PowerShot A100          2002            1280            1024
# ...

# %%
# Por ultimo podemos exportar el data frame a una archivo excel
df_merged.to_excel("camaras.xls", sheet_name="datos")

# %%
# Tambien podemos exportarlo a un archivo csv
df_merged.to_csv("camaras.csv")
